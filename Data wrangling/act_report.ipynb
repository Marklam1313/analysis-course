# %% [markdown]
# ## Report: act_report
# * Create a **250-word-minimum written report** called "act_report.pdf" or "act_report.html" that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.

# %% [markdown]
# The first insight is to identify the most frequent dog breeds in the dataset. We did that based on neural network image prediction model. We measured by using the method .value_counts() of the column 'p1'. We found that golden retriever has been mentioned 139 times, labrador retriver has been mentioned 93 times, and pembroke has been mentioned 88 times.
#
# The second insight is to identify the most popular dog breed from the top 10 frequently mentioned dog breeds by measuring the average like counts from the tweets they are mentioned. We do that by preparing a list of most frequently mentioned dog breeds, and using the method .groupby and .mean() to store the average like counts of each breed. We found that samoyed ranks first with 11573 likes (favourites) for each appearance in a tweet. Golden retriver ranks the second with 10924 likes (favourties) for each appearance in a tweet. Labrador retriever ranks third with 10157 likes (favourites) for each appearance in a tweet. We can see that these breeds are the most popular.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The third insight is to see the correlation between the number of retweets and like (favourites). We found that they have a very positive correlation (0.926). It tells that the two variables tend to move in the same direction, one variable would increase as the other increases, and would decrease as the other decreases. As we can see from below plot, as the number of retweet increases, the number of like (favourites) increases too. It shows that when people find the content of the tweet interesting, they would tend to like and retweet more.

# %% [markdown]
# ![image.png](attachment:image.png)
